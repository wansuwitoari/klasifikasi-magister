# %%
import pandas as pd
import numpy as np

df_2015 = pd.read_excel("2015.xlsx")
df_2015.head(5)
# Out:
#       No_Pendaftaran            Nama_Lengkap                    Asal_Kampus  \
# 0  10675075374430399  A.Maulidinnawati A.K.P               STMIK Dipanegara
# 1  11209411540826374        AAN JELLI PRIANA  UNIVERSITAS KANJURUHAN MALANG
# 2  11072383693015420           Asyrofa Rahmi          Universitas Brawijaya
# 3  11038030292359124    Fitriyatul Qomariyah   Universitas Trunojoyo Madura
# 4  11063918269209172             IDA WAHYUNI              STMIK ASIA MALANG
#
#                                  Bidang_Minat  Motivasi_Studi  \
# 0                    Rekayasa Perangkat Lunak              70
# 1  Teknologi Media, Game dan Piranti Bergerak              75
# 2                               Sistem Cerdas              80
# 3                               Sistem Cerdas              80
# 4                               Sistem Cerdas              90
#
#    Motivasi_Beasiswa  Pengalaman_Penelitian  Rencana_Riset  Komunikasi  \
# ...

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             25 non-null     int64
#  1   Nama_Lengkap               25 non-null     object
#  2   Asal_Kampus                25 non-null     object
#  3   Bidang_Minat               25 non-null     object
#  4   Motivasi_Studi             25 non-null     int64
#  5   Motivasi_Beasiswa          25 non-null     int64
#  6   Pengalaman_Penelitian      25 non-null     int64
#  7   Rencana_Riset              25 non-null     int64
#  8   Komunikasi                 25 non-null     int64
#  9   Problem_Solving            25 non-null     int64
#  10  Literatur_Review           25 non-null     int64
#  11  Team_Work                  25 non-null     int64
#  12  Nilai_Total_Interview      25 non-null     float64
# ...

# %%
df_2016 = pd.read_excel("2016.xlsx")
df_2016.head(5)
# Out:
#    No_Pendaftaran              Nama_Lengkap                Asal_Kampus  \
# 0   1502161100025       Agung Mustika Rizki      Universitas Brawijaya
# 1   1502161100029      Alfita Rakhmandasari      Universitas Brawijaya
# 2   1502161100009  Baskoro Singgih Anindito  Universitas Negeri Malang
# 3   1502161100016   Diny Melsye Nurul Fajri      Universitas Brawijaya
# 4   1502161100027        Frihandika Permana  Universitas Negeri Malang
#
#                                  Bidang_Minat  Motivasi_Studi  \
# 0                               Sistem Cerdas              85
# 1                               Sistem Cerdas              75
# 2                 Jaringan Berbasis Informasi              85
# 3                               Sistem Cerdas              85
# 4  Teknologi Media, Game dan Piranti Bergerak              80
#
#    Motivasi_Beasiswa  Pengalaman_Penelitian  Rencana_Riset  Komunikasi  \
# 0                 80                     70             70          75
# ...

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             32 non-null     int64
#  1   Nama_Lengkap               32 non-null     object
#  2   Asal_Kampus                32 non-null     object
#  3   Bidang_Minat               32 non-null     object
#  4   Motivasi_Studi             32 non-null     int64
#  5   Motivasi_Beasiswa          32 non-null     int64
#  6   Pengalaman_Penelitian      32 non-null     int64
#  7   Rencana_Riset              32 non-null     int64
#  8   Komunikasi                 32 non-null     int64
#  9   Problem_Solving            32 non-null     int64
#  10  Literatur_Review           32 non-null     int64
#  11  Team_Work                  32 non-null     int64
#  12  Nilai_Total_Interview      32 non-null     float64
# ...

# %%
df_2017 = pd.read_excel("2017.xlsx")
df_2017.head(5)
# Out:
#    No_Pendaftaran                   Nama_Lengkap                Asal_Kampus  \
# 0   1502171100056                  Ahmad Baihaqi  UIN MAULANA MALIK IBRAHIM
# 1   1502171100016                 Ananto Setyo W      UNIVERSITAS BRAWIJAYA
# 2   1502171100022  Anggia Dini M B P Simorangkir      UNIVERSITAS BRAWIJAYA
# 3   1502171100001          Aulia Akhrian Syahidi         STIKIP BANJARMASIN
# 4   1502171100043                 Aulia Mas'adah  UIN MAULANA MALIK IBRAHIM
#
#                                  Bidang_Minat  Motivasi_Studi  \
# 0                            Sistem Informasi              80
# 1                               Sistem Cerdas              80
# 2                               Sistem Cerdas              80
# 3  Teknologi Media, Game dan Piranti Bergerak              80
# 4                            Sistem Informasi              85
#
#    Motivasi_Beasiswa  Pengalaman_Penelitian  Rencana_Riset  Komunikasi  \
# ...

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             45 non-null     int64
#  1   Nama_Lengkap               45 non-null     object
#  2   Asal_Kampus                45 non-null     object
#  3   Bidang_Minat               45 non-null     object
#  4   Motivasi_Studi             45 non-null     int64
#  5   Motivasi_Beasiswa          45 non-null     int64
#  6   Pengalaman_Penelitian      45 non-null     int64
#  7   Rencana_Riset              44 non-null     float64
#  8   Komunikasi                 45 non-null     int64
#  9   Problem_Solving            45 non-null     int64
#  10  Literatur_Review           45 non-null     int64
#  11  Team_Work                  45 non-null     int64
#  12  Nilai_Total_Interview      45 non-null     float64
# ...

# %%
df_2018 = pd.read_excel("2018.xlsx")
df_2018.head(5)
# Out:
#    No_Pendaftaran                    Nama_Lengkap  \
# 0   1502181100025            Ahmad Syarif Hidayat
# 1   1502191100006  Ahmad Wali Satria Bahari Johan
# 2   1502181100031           Beryl Labique Ahmadie
# 3   1502181100033           Bobby Apryanto Sander
# 4   1502181100030           Budi Fajar Supriyanto
#
#                       Asal_Kampus                                Bidang_Minat  \
# 0           Universitas Gunadarma                               Sistem Cerdas
# 1         Polteknik Negeri Malang                    Rekayasa Perangkat Lunak
# 2           UNIVERSITAS BRAWIJAYA                               Sistem Cerdas
# 3  UNIVERSITAS KOMPUTER INDONESIA                            Sistem Informasi
# 4               STMIK Asia Malang  Teknologi Media, Game dan Piranti Bergerak
#
#    Motivasi_Studi  Motivasi_Beasiswa  Pengalaman_Penelitian  Rencana_Riset  \
# 0              85                 80                     70             70
# ...

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             38 non-null     int64
#  1   Nama_Lengkap               38 non-null     object
#  2   Asal_Kampus                38 non-null     object
#  3   Bidang_Minat               38 non-null     object
#  4   Motivasi_Studi             38 non-null     int64
#  5   Motivasi_Beasiswa          38 non-null     int64
#  6   Pengalaman_Penelitian      38 non-null     int64
#  7   Rencana_Riset              38 non-null     int64
#  8   Komunikasi                 38 non-null     int64
#  9   Problem_Solving            38 non-null     int64
#  10  Literatur_Review           38 non-null     int64
#  11  Team_Work                  38 non-null     int64
#  12  Nilai_Total_Interview      38 non-null     float64
# ...

# %%
df = pd.concat([df_2015, df_2016,df_2017,df_2018])
df.shape
# Out:
# (140, 27)

# %%
df.to_excel("output.xlsx")

# %%
print(df.columns.tolist())
# Out:
# ['Bidang_Minat', 'Motivasi_Studi', 'Motivasi_Beasiswa', 'Pengalaman_Penelitian', 'Rencana_Riset', 'Komunikasi', 'Problem_Solving', 'Literatur_Review', 'Team_Work', 'Nilai_Total_Interview', 'Jenis_TOEFL', 'Nilai__Setara_TOEFL', 'Jenis_TPA', 'Nilai_TPA', 'Matematika_Komputasi', 'Jaringan', 'Basis_Data', 'Algoritma_dan_Pemrograman', 'Nilai_Tes_Bidang', 'Akreditasi_Kampus', 'Nilai_Setara_IPK', 'Jenis_Beasiswa', 'Nilai_Total', 'Kategori_Lulus']

# %%
df.head(5)
# Out:
#       No_Pendaftaran            Nama_Lengkap                    Asal_Kampus  \
# 0  10675075374430399  A.Maulidinnawati A.K.P               STMIK Dipanegara
# 1  11209411540826374        AAN JELLI PRIANA  UNIVERSITAS KANJURUHAN MALANG
# 2  11072383693015420           Asyrofa Rahmi          Universitas Brawijaya
# 3  11038030292359124    Fitriyatul Qomariyah   Universitas Trunojoyo Madura
# 4  11063918269209172             IDA WAHYUNI              STMIK ASIA MALANG
#
#                                  Bidang_Minat  Motivasi_Studi  \
# 0                    Rekayasa Perangkat Lunak              70
# 1  Teknologi Media, Game dan Piranti Bergerak              75
# 2                               Sistem Cerdas              80
# 3                               Sistem Cerdas              80
# 4                               Sistem Cerdas              90
#
#    Motivasi_Beasiswa  Pengalaman_Penelitian  Rencana_Riset  Komunikasi  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 37
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             140 non-null    int64
#  1   Nama_Lengkap               140 non-null    object
#  2   Asal_Kampus                140 non-null    object
#  3   Bidang_Minat               140 non-null    object
#  4   Motivasi_Studi             140 non-null    int64
#  5   Motivasi_Beasiswa          140 non-null    int64
#  6   Pengalaman_Penelitian      140 non-null    int64
#  7   Rencana_Riset              139 non-null    float64
#  8   Komunikasi                 140 non-null    int64
#  9   Problem_Solving            140 non-null    int64
#  10  Literatur_Review           140 non-null    int64
#  11  Team_Work                  140 non-null    int64
#  12  Nilai_Total_Interview      140 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# No_Pendaftaran                0
# Nama_Lengkap                  0
# Asal_Kampus                   0
# Bidang_Minat                  0
# Motivasi_Studi                0
# Motivasi_Beasiswa             0
# Pengalaman_Penelitian         0
# Rencana_Riset                 1
# Komunikasi                    0
# Problem_Solving               0
# Literatur_Review              0
# Team_Work                     0
# Nilai_Total_Interview         0
# Jenis_TOEFL                  10
# Nilai__Setara_TOEFL           0
# Jenis_TPA                     4
# Nilai_TPA                     0
# Matematika_Komputasi          0
# Jaringan                      0
# Basis_Data                    0
# Algoritma_dan_Pemrograman     0
# Nilai_Tes_Bidang              0
# Akreditasi_Kampus             0
# Nilai_Setara_IPK              0
# Jenis_Beasiswa               50
# Nilai_Total                   0
# Kategori_Lulus                0
# dtype: int64

# %%
df["Rencana_Riset"].min()
# Out:
# 50.0

# %%
df["Rencana_Riset"] = df["Rencana_Riset"].fillna(value=df["Rencana_Riset"].min())

# %%
df[["Jenis_TOEFL","Jenis_Beasiswa"]]
# Out:
#    Jenis_TOEFL Jenis_Beasiswa
# 0    Tidak Ada            NaN
# 1    Tidak Ada            NaN
# 2    Tidak Ada           Gold
# 3          ITP            NaN
# 4          iBT            NaN
# ..         ...            ...
# 33   Tidak Ada          Tidak
# 34   Tidak Ada          Tidak
# 35         iBT          Tidak
# 36         iBT          Tidak
# 37         ITP          Tidak
#
# [140 rows x 2 columns]

# %%
df["Jenis_TOEFL"].fillna("Tidak Ada", inplace=True)
df["Jenis_TPA"].fillna("Tidak Ada", inplace=True)
df["Jenis_Beasiswa"].fillna("Tidak", inplace=True)

# %%
df[["Jenis_TOEFL","Jenis_TPA","Jenis_Beasiswa"]]
# Out:
#    Jenis_TOEFL     Jenis_TPA Jenis_Beasiswa
# 0    Tidak Ada     Tidak Ada          Tidak
# 1    Tidak Ada     Tidak Ada          Tidak
# 2    Tidak Ada  OTO Bappenas           Gold
# 3          ITP  OTO Bappenas          Tidak
# 4          iBT     Tidak Ada          Tidak
# ..         ...           ...            ...
# 33   Tidak Ada     Tidak Ada          Tidak
# 34   Tidak Ada     Tidak Ada          Tidak
# 35         iBT  OTO Bappenas          Tidak
# 36         iBT  OTO Bappenas          Tidak
# 37         ITP  OTO Bappenas          Tidak
#
# [140 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# No_Pendaftaran               0
# Nama_Lengkap                 0
# Asal_Kampus                  0
# Bidang_Minat                 0
# Motivasi_Studi               0
# Motivasi_Beasiswa            0
# Pengalaman_Penelitian        0
# Rencana_Riset                0
# Komunikasi                   0
# Problem_Solving              0
# Literatur_Review             0
# Team_Work                    0
# Nilai_Total_Interview        0
# Jenis_TOEFL                  0
# Nilai__Setara_TOEFL          0
# Jenis_TPA                    0
# Nilai_TPA                    0
# Matematika_Komputasi         0
# Jaringan                     0
# Basis_Data                   0
# Algoritma_dan_Pemrograman    0
# Nilai_Tes_Bidang             0
# Akreditasi_Kampus            0
# Nilai_Setara_IPK             0
# Jenis_Beasiswa               0
# Nilai_Total                  0
# Kategori_Lulus               0
# dtype: int64

# %% [markdown]
# ENCODE

# %%
df["Bidang_Minat"].replace(
    {"Rekayasa Perangkat Lunak" : 1,
     "Teknologi Media, Game dan Piranti Bergerak" : 2, 
     "Sistem Cerdas" : 3,
     "Jaringan Berbasis Informasi" : 4,
     "Sistem Informasi" : 5}, 
    inplace=True)

# %%
df["Jenis_TOEFL"].replace(
    {"Tidak Ada" : 1,
     "Preparation" : 2, 
     "iBT" : 3,
     "ITP" : 4}, 
    inplace=True)

# %%
df["Jenis_TPA"].replace(
    {"Tidak Ada" : 1,
     "Lokal" : 2,
     "OTO Bappenas" : 3},
    inplace=True)

# %%
df["Akreditasi_Kampus"].replace(
    {"Negeri Unggulan" : 5,
     "Negeri Non Unggulan" : 3,
     "Swasta Unggulan" : 4,
     "Swasta Non Unggulan" : 2,
     "Swasta Biasa" : 1},
    inplace=True)

# %%
df["Jenis_Beasiswa"].replace(
    {"Tidak" : 1, 
     "Silver" : 2, 
     "Gold" : 3,
     "Diamond" : 4}, 
    inplace=True)

# %%
df["Kategori_Lulus"].replace(
    {"Tidak Lulus Tepat Waktu" : 1,
     "Lulus Tepat Waktu" : 0},
    inplace=True)

# %%
df[["Bidang_Minat","Jenis_TOEFL","Jenis_TPA","Akreditasi_Kampus","Jenis_Beasiswa","Kategori_Lulus"]]
# Out:
#     Bidang_Minat  Jenis_TOEFL  Jenis_TPA  Akreditasi_Kampus  Jenis_Beasiswa  \
# 0              1            1          1                  2               1
# 1              2            1          1                  2               1
# 2              3            1          3                  5               3
# 3              3            4          3                  3               1
# 4              3            3          1                  2               1
# ..           ...          ...        ...                ...             ...
# 33             3            1          1                  5               1
# 34             5            1          1                  5               1
# 35             5            3          3                  2               1
# 36             5            3          3                  5               1
# 37             3            4          3                  5               1
#
#     Kategori_Lulus
# 0                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 37
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             140 non-null    int64
#  1   Nama_Lengkap               140 non-null    object
#  2   Asal_Kampus                140 non-null    object
#  3   Bidang_Minat               140 non-null    int64
#  4   Motivasi_Studi             140 non-null    int64
#  5   Motivasi_Beasiswa          140 non-null    int64
#  6   Pengalaman_Penelitian      140 non-null    int64
#  7   Rencana_Riset              140 non-null    float64
#  8   Komunikasi                 140 non-null    int64
#  9   Problem_Solving            140 non-null    int64
#  10  Literatur_Review           140 non-null    int64
#  11  Team_Work                  140 non-null    int64
#  12  Nilai_Total_Interview      140 non-null    float64
# ...

# %%
df["Bidang_Minat"] = df["Bidang_Minat"].astype(str).astype(float)
df["Motivasi_Studi"] = df["Motivasi_Studi"].astype(str).astype(float)
df["Motivasi_Beasiswa"] = df["Motivasi_Beasiswa"].astype(str).astype(float)
df["Pengalaman_Penelitian"] = df["Pengalaman_Penelitian"].astype(str).astype(float)
df["Komunikasi"] = df["Komunikasi"].astype(str).astype(float)
df["Problem_Solving"] = df["Problem_Solving"].astype(str).astype(float)
df["Literatur_Review"] = df["Literatur_Review"].astype(str).astype(float)
df["Team_Work"] = df["Team_Work"].astype(str).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 37
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   No_Pendaftaran             140 non-null    int64
#  1   Nama_Lengkap               140 non-null    object
#  2   Asal_Kampus                140 non-null    object
#  3   Bidang_Minat               140 non-null    float64
#  4   Motivasi_Studi             140 non-null    float64
#  5   Motivasi_Beasiswa          140 non-null    float64
#  6   Pengalaman_Penelitian      140 non-null    float64
#  7   Rencana_Riset              140 non-null    float64
#  8   Komunikasi                 140 non-null    float64
#  9   Problem_Solving            140 non-null    float64
#  10  Literatur_Review           140 non-null    float64
#  11  Team_Work                  140 non-null    float64
#  12  Nilai_Total_Interview      140 non-null    float64
# ...

# %%
df = df.drop(columns=['No_Pendaftaran','Nama_Lengkap','Asal_Kampus'])

# %%
df
# Out:
#     Bidang_Minat  Motivasi_Studi  Motivasi_Beasiswa  Pengalaman_Penelitian  \
# 0            1.0            70.0               80.0                   70.0
# 1            2.0            75.0               80.0                   70.0
# 2            3.0            80.0               80.0                   70.0
# 3            3.0            80.0               80.0                   70.0
# 4            3.0            90.0               80.0                   75.0
# ..           ...             ...                ...                    ...
# 33           3.0            70.0               70.0                   80.0
# 34           5.0            80.0               75.0                   70.0
# 35           5.0            85.0               75.0                   70.0
# 36           5.0            85.0               75.0                   70.0
# 37           3.0            80.0               75.0                   70.0
#
# ...

# %%
df.min()
# Out:
# Bidang_Minat                  1.000
# Motivasi_Studi               50.000
# Motivasi_Beasiswa            70.000
# Pengalaman_Penelitian        50.000
# Rencana_Riset                50.000
# Komunikasi                   50.000
# Problem_Solving              50.000
# Literatur_Review             50.000
# Team_Work                    50.000
# Nilai_Total_Interview        55.625
# Jenis_TOEFL                   1.000
# Nilai__Setara_TOEFL          40.000
# Jenis_TPA                     1.000
# Nilai_TPA                     8.000
# Matematika_Komputasi          0.000
# Jaringan                      0.000
# Basis_Data                    6.670
# Algoritma_dan_Pemrograman     4.000
# Nilai_Tes_Bidang             16.680
# Akreditasi_Kampus             1.000
# Nilai_Setara_IPK             61.840
# Jenis_Beasiswa                1.000
# Nilai_Total                  43.600
# Kategori_Lulus                0.000
# dtype: float64

# %%
df.max()
# Out:
# Bidang_Minat                   5.00
# Motivasi_Studi                90.00
# Motivasi_Beasiswa             90.00
# Pengalaman_Penelitian         90.00
# Rencana_Riset                 90.00
# Komunikasi                    90.00
# Problem_Solving               90.00
# Literatur_Review              90.00
# Team_Work                     90.00
# Nilai_Total_Interview         86.00
# Jenis_TOEFL                    4.00
# Nilai__Setara_TOEFL          102.27
# Jenis_TPA                      3.00
# Nilai_TPA                    113.34
# Matematika_Komputasi          60.03
# Jaringan                      60.03
# Basis_Data                    93.33
# Algoritma_dan_Pemrograman     93.38
# Nilai_Tes_Bidang              70.14
# Akreditasi_Kampus              5.00
# Nilai_Setara_IPK              95.50
# Jenis_Beasiswa                 4.00
# Nilai_Total                   85.00
# Kategori_Lulus                 1.00
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 37
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bidang_Minat               140 non-null    float64
#  1   Motivasi_Studi             140 non-null    float64
#  2   Motivasi_Beasiswa          140 non-null    float64
#  3   Pengalaman_Penelitian      140 non-null    float64
#  4   Rencana_Riset              140 non-null    float64
#  5   Komunikasi                 140 non-null    float64
#  6   Problem_Solving            140 non-null    float64
#  7   Literatur_Review           140 non-null    float64
#  8   Team_Work                  140 non-null    float64
#  9   Nilai_Total_Interview      140 non-null    float64
#  10  Jenis_TOEFL                140 non-null    int64
#  11  Nilai__Setara_TOEFL        140 non-null    float64
#  12  Jenis_TPA                  140 non-null    int64
# ...

# %%
X = df.drop("Kategori_Lulus",axis =1)
y = df["Kategori_Lulus"]

print(y)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 33    1
# 34    1
# 35    1
# 36    1
# 37    1
# Name: Kategori_Lulus, Length: 140, dtype: int64

# %%
X
# Out:
#     Bidang_Minat  Motivasi_Studi  Motivasi_Beasiswa  Pengalaman_Penelitian  \
# 0            1.0            70.0               80.0                   70.0
# 1            2.0            75.0               80.0                   70.0
# 2            3.0            80.0               80.0                   70.0
# 3            3.0            80.0               80.0                   70.0
# 4            3.0            90.0               80.0                   75.0
# ..           ...             ...                ...                    ...
# 33           3.0            70.0               70.0                   80.0
# 34           5.0            80.0               75.0                   70.0
# 35           5.0            85.0               75.0                   70.0
# 36           5.0            85.0               75.0                   70.0
# 37           3.0            80.0               75.0                   70.0
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((112, 23), (28, 23), (112,), (28,))

# %%
X_train
# Out:
#     Bidang_Minat  Motivasi_Studi  Motivasi_Beasiswa  Pengalaman_Penelitian  \
# 28           2.0            80.0               80.0                   75.0
# 21           3.0            80.0               80.0                   70.0
# 21           2.0            75.0               75.0                   70.0
# 18           3.0            75.0               80.0                   80.0
# 9            4.0            70.0               80.0                   70.0
# ..           ...             ...                ...                    ...
# 25           2.0            80.0               80.0                   80.0
# 40           5.0            75.0               75.0                   70.0
# 24           5.0            85.0               70.0                   75.0
# 23           2.0            80.0               70.0                   75.0
# 8            1.0            85.0               80.0                   70.0
#
# ...

# %%
y_train
# Out:
# 28    1
# 21    0
# 21    1
# 18    0
# 9     0
#      ..
# 25    0
# 40    1
# 24    1
# 23    1
# 8     0
# Name: Kategori_Lulus, Length: 112, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.9285714285714286

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        16
#            1       0.86      1.00      0.92        12
#
#     accuracy                           0.93        28
#    macro avg       0.93      0.94      0.93        28
# weighted avg       0.94      0.93      0.93        28

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(model, X, y, cv=5)
# Out:
# array([0.82142857, 0.78571429, 0.71428571, 1.        , 1.        ])

# %%
cross_val_score(model, X, y, cv=5).mean()
# Out:
# 0.8642857142857142

# %%
model.predict([[2,80,80,75,75,80,78,80,80,78.3,4,75,3,95.37,20,40,28,16,43.42,1,76.7125,2,66.43]])
# Out:
# F:\SKIRPSI FIXXX\magister\env\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.predict_proba([[2,80,80,75,75,80,78,80,80,78.3,4,75,3,95.37,20,40,28,16,43.42,1,76.7125,2,66.43]])
# Out:
# F:\SKIRPSI FIXXX\magister\env\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([[0.89721604, 0.10278396]])

# %%
x = model.predict_proba([[5,80,80,75,75,50,78,70,80,78.3,4,102,3,95.37,20,40,100,16,43.42,1,76,2,66.43]])
# Out:
# F:\SKIRPSI FIXXX\magister\env\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
x
# Out:
# array([[0.2232699, 0.7767301]])

# %%
x[0][0] + x[0][1]
# Out:
# 1.0000000000000107

# %%
x = model.predict_proba([[1,85,90,85,86,90,90,85,90,85,1,100,1,80,80,80,80,140,67,1,100,1,100]])
# Out:
# F:\SKIRPSI FIXXX\magister\env\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
x
# Out:
# array([[3.0234627e-12, 1.0000000e+00]])

# %%
x[0][0] + x[0][1]
# Out:
# 1.0000000000000107

# %%
import pickle

pickle.dump(model, open('modelnb.pkl','wb'))
